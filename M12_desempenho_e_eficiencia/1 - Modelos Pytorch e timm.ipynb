# %% [markdown]
# # Análise de modelos pré-treinados disponíveis
#
# Para visualizar os gráficos abra o notebook usando este botão:
#
# [![nbviewer](https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg)](https://nbviewer.org/github/chcomin/curso-visao-computacional-2024/blob/main/M12_desempenho_e_eficiencia/1%20-%20Modelos%20Pytorch%20e%20timm.ipynb)

# %% [markdown]
# ### Modelos de classificação disponíveis no Pytorch

# %%
import re

import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = 'notebook_connected'

df = pd.read_csv('../data/model_info/models.csv', skipinitialspace=True)
df['Params'] = df['Params'].str.replace('M', '').astype(float)
family = []
for name in df['Weight']:
    family.append(re.split(r'\d|_', name)[0])
df['Família'] = family
df
# Out:
#                                      Weight   Acc@1   Acc@5  Params  GFLOPS  \
# 0             AlexNet_Weights.IMAGENET1K_V1  56.522  79.066    61.1    0.71
# 1       ConvNeXt_Base_Weights.IMAGENET1K_V1  84.062  96.870    88.6   15.36
# 2      ConvNeXt_Large_Weights.IMAGENET1K_V1  84.414  96.976   197.8   34.36
# 3      ConvNeXt_Small_Weights.IMAGENET1K_V1  83.616  96.650    50.2    8.68
# 4       ConvNeXt_Tiny_Weights.IMAGENET1K_V1  82.520  96.146    28.6    4.46
# ..                                      ...     ...     ...     ...     ...
# 110          ViT_L_32_Weights.IMAGENET1K_V1  76.972  93.070   306.5   15.38
# 111  Wide_ResNet101_2_Weights.IMAGENET1K_V1  78.848  94.284   126.9   22.75
# 112  Wide_ResNet101_2_Weights.IMAGENET1K_V2  82.510  96.020   126.9   22.75
# 113   Wide_ResNet50_2_Weights.IMAGENET1K_V1  78.468  94.086    68.9   11.40
# 114   Wide_ResNet50_2_Weights.IMAGENET1K_V2  81.602  95.758    68.9   11.40
#
#             Type   Família
# 0            CNN   AlexNet
# 1            CNN  ConvNeXt
# 2            CNN  ConvNeXt
# 3            CNN  ConvNeXt
# 4            CNN  ConvNeXt
# ..           ...       ...
# 110  Transformer       ViT
# 111          CNN      Wide
# 112          CNN      Wide
# 113          CNN      Wide
# 114          CNN      Wide
#
# [115 rows x 7 columns]

# %%
fig1 = px.scatter(
    df, x='Params', y='Acc@1', hover_data=['Weight', 'GFLOPS'],
    log_x=True, color='Família', 
    title='Acurácia dos modelos de classificação do Pytorch em função do número de parâmetros')
fig1.update_traces(marker={'size': 4})
fig2 = px.scatter(
    df, x='GFLOPS', y='Acc@1', hover_data=['Weight', 'Params'],
    log_x=True, color='Família',
    title='Acurácia dos modelos de classificação do Pytorch em função do GFLOPS')
fig2.update_traces(marker={'size': 4})
fig1.show()
fig2.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="a6977de0-452d-4f47-81a6-7c0e6768e0d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a6977de0-452d-4f47-81a6-7c0e6768e0d3")) {                    Plotly.newPlot(                        "a6977de0-452d-4f47-81a6-7c0e6768e0d3",                        [{"customdata":[["AlexNet_Weights.IMAGENET1K_V1",0.71]],"hovertemplate":"Fam\u00edlia=AlexNet\u003cbr\u003eParams=%{x}\u003cbr\u003eAcc@1=%{y}\u003cbr\u003eWeight=%{customdata[0]}\u003cbr\u003eGFLOPS=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AlexNet","marker":{"color":"#636efa","symbol":"circle","size":4},"mode":"markers","name":"AlexNet","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"zczMzMyMTkA="},"xaxis":"x","y":{"dtype":"f8","bdata":"iUFg5dBCTEA="},"yaxis":"y","type":"scatter"},{"customdata":[["ConvNeXt_Base_Weights.IMAGENET1K_V1",15.36],["ConvNeXt_Large_Weights.IMAGENET1K_V1",34.36],["ConvNeXt_Small_Weights.IMAGENET1K_V1",8.68],["ConvNeXt_Tiny_Weights.IMAGENET1K_V1",4.46]],"hovertemplate":"Fam\u00edlia=ConvNeXt\u003cbr\u003eParams=%{x}\u003cbr\u003eAcc@1=%{y}\u003cbr\u003eWeight=%{customdata[0]}\u003cbr\u003eGFLOPS=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ConvNeXt","marker":{"color":"#EF553B","symbol":"circle","size":4},"mode":"markers","name":"ConvNeXt","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"ZmZmZmYmVkCamZmZmbloQJqZmZmZGUlAmpmZmZmZPEA="},"xaxis":"x","y":{"dtype":"f8","bdata":"hxbZzvcDVUDRItv5fhpVQIGVQ4ts51RA4XoUrkehVEA="},"yaxis":"y","type":"scatter"},{"customdata":[["DenseNet121_Weights.IMAGENET1K_V1",2.83],["DenseNet161_Weights.IMAGENET1K_V1",7.73],["DenseNet169_Weights.IMAGENET1K_V1",3.36],["DenseNet201_Weights.IMAGENET1K_V1",4.29]],"hovertemplate":"Fam\u00edlia=DenseNet\u003cbr\u003eParams=%{x}\u003cbr\u003eAcc@1=%{y}\u003cbr\u003eWeight=%{customdata[0]}\u003cbr\u003eGFLOPS=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DenseNet","marker":{"color":"#00cc96","symbol":"circle","size":4},"mode":"markers","name":"DenseNet","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAIEAzMzMzM7M8QDMzMzMzMyxAAAAAAAAANEA="},"xaxis":"x","y":{"dtype":"f8","bdata":"sp3vp8abUkBGtvP91EhTQGZmZmZm5lJA001iEFg5U0A="},"yaxis":"y","type":"scatter"},{"customdata":[["EfficientNet_B0_Weights.IMAGENET1K_V1",0.39],["EfficientNet_B1_Weights.IMAGENET1K_V1",0.69],["EfficientNet_B1_Weights.IMAGENET1K_V2",0.69],["EfficientNet_B2_Weights.IMAGENET1K_V1",1.09],["EfficientNet_B3_Weights.IMAGENET1K_V1",1.83],["EfficientNet_B4_Weights.IMAGENET1K_V1",4.39],["EfficientNet_B5_Weights.IMAGENET1K_V1",10.27],["EfficientNet_B6_Weights.IMAGENET1K_V1",19.07],["EfficientNet_B7_Weights.IMAGENET1K_V1",37.75],["EfficientNet_V2_L_Weights.IMAGENET1K_V1",56.08],["EfficientNet_V2_M_Weights.IMAGENET1K_V1",24.58],["EfficientNet_V2_S_Weights.IMAGENET1K_V1",8.37]],"hovertemplate":"Fam\u00edlia=EfficientNet\u003cbr\u003eParams=%{x}\u003cbr\u003eAcc@1=%{y}\u003cbr\u003eWeight=%{customdata[0]}\u003cbr\u003eGFLOPS=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EfficientNet","marker":{"color":"#ab63fa","symbol":"circle","size":4},"mode":"markers","name":"EfficientNet","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"MzMzMzMzFUAzMzMzMzMfQDMzMzMzMx9AMzMzMzMzIkBmZmZmZmYoQM3MzMzMTDNAZmZmZmZmPkAAAAAAAIBFQDMzMzMzk1BAAAAAAACgXUDNzMzMzAxLQAAAAAAAgDVA"},"xaxis":"x","y":{"dtype":"f8","bdata":"PzVeuklsU0AMAiuHFqlTQBKDwMqh9VNA9P3UeOkmVECNl24Sg4BUQH9qvHST2FRAI9v5fmrcVECNl24SgwBVQCuHFtnOB1VAwcqhRbZzVUC6SQwCK0dVQDvfT42XDlVA"},"yaxis":"y","type":"scatter"},{"customdata":[["GoogLeNet_Weights.IMAGENET1K_V1",1.5]],"hovertemplate":"Fam\u00edlia=GoogLeNet\u003cbr\u003eParams=%{x}\u003cbr\u003e ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="6f6bcbe8-fa0e-47e0-b839-903be2f77aca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6f6bcbe8-fa0e-47e0-b839-903be2f77aca")) {                    Plotly.newPlot(                        "6f6bcbe8-fa0e-47e0-b839-903be2f77aca",                        [{"customdata":[["AlexNet_Weights.IMAGENET1K_V1",61.1]],"hovertemplate":"Fam\u00edlia=AlexNet\u003cbr\u003eGFLOPS=%{x}\u003cbr\u003eAcc@1=%{y}\u003cbr\u003eWeight=%{customdata[0]}\u003cbr\u003eParams=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AlexNet","marker":{"color":"#636efa","symbol":"circle","size":4},"mode":"markers","name":"AlexNet","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"uB6F61G45j8="},"xaxis":"x","y":{"dtype":"f8","bdata":"iUFg5dBCTEA="},"yaxis":"y","type":"scatter"},{"customdata":[["ConvNeXt_Base_Weights.IMAGENET1K_V1",88.6],["ConvNeXt_Large_Weights.IMAGENET1K_V1",197.8],["ConvNeXt_Small_Weights.IMAGENET1K_V1",50.2],["ConvNeXt_Tiny_Weights.IMAGENET1K_V1",28.6]],"hovertemplate":"Fam\u00edlia=ConvNeXt\u003cbr\u003eGFLOPS=%{x}\u003cbr\u003eAcc@1=%{y}\u003cbr\u003eWeight=%{customdata[0]}\u003cbr\u003eParams=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ConvNeXt","marker":{"color":"#EF553B","symbol":"circle","size":4},"mode":"markers","name":"ConvNeXt","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"uB6F61G4LkCuR+F6FC5BQFyPwvUoXCFA16NwPQrXEUA="},"xaxis":"x","y":{"dtype":"f8","bdata":"hxbZzvcDVUDRItv5fhpVQIGVQ4ts51RA4XoUrkehVEA="},"yaxis":"y","type":"scatter"},{"customdata":[["DenseNet121_Weights.IMAGENET1K_V1",8.0],["DenseNet161_Weights.IMAGENET1K_V1",28.7],["DenseNet169_Weights.IMAGENET1K_V1",14.1],["DenseNet201_Weights.IMAGENET1K_V1",20.0]],"hovertemplate":"Fam\u00edlia=DenseNet\u003cbr\u003eGFLOPS=%{x}\u003cbr\u003eAcc@1=%{y}\u003cbr\u003eWeight=%{customdata[0]}\u003cbr\u003eParams=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DenseNet","marker":{"color":"#00cc96","symbol":"circle","size":4},"mode":"markers","name":"DenseNet","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"pHA9CtejBkDsUbgeheseQOF6FK5H4QpAKVyPwvUoEUA="},"xaxis":"x","y":{"dtype":"f8","bdata":"sp3vp8abUkBGtvP91EhTQGZmZmZm5lJA001iEFg5U0A="},"yaxis":"y","type":"scatter"},{"customdata":[["EfficientNet_B0_Weights.IMAGENET1K_V1",5.3],["EfficientNet_B1_Weights.IMAGENET1K_V1",7.8],["EfficientNet_B1_Weights.IMAGENET1K_V2",7.8],["EfficientNet_B2_Weights.IMAGENET1K_V1",9.1],["EfficientNet_B3_Weights.IMAGENET1K_V1",12.2],["EfficientNet_B4_Weights.IMAGENET1K_V1",19.3],["EfficientNet_B5_Weights.IMAGENET1K_V1",30.4],["EfficientNet_B6_Weights.IMAGENET1K_V1",43.0],["EfficientNet_B7_Weights.IMAGENET1K_V1",66.3],["EfficientNet_V2_L_Weights.IMAGENET1K_V1",118.5],["EfficientNet_V2_M_Weights.IMAGENET1K_V1",54.1],["EfficientNet_V2_S_Weights.IMAGENET1K_V1",21.5]],"hovertemplate":"Fam\u00edlia=EfficientNet\u003cbr\u003eGFLOPS=%{x}\u003cbr\u003eAcc@1=%{y}\u003cbr\u003eWeight=%{customdata[0]}\u003cbr\u003eParams=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EfficientNet","marker":{"color":"#ab63fa","symbol":"circle","size":4},"mode":"markers","name":"EfficientNet","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"9ihcj8L12D8UrkfhehTmPxSuR+F6FOY\u002fcT0K16Nw8T9I4XoUrkf9P4\u002fC9ShcjxFACtejcD2KJEBSuB6F6xEzQAAAAAAA4EJACtejcD0KTEAUrkfhepQ4QD0K16NwvSBA"},"xaxis":"x","y":{"dtype":"f8","bdata":"PzVeuklsU0AMAiuHFqlTQBKDwMqh9VNA9P3UeOkmVECNl24Sg4BUQH9qvHST2FRAI9v5fmrcVECNl24SgwBVQCuHFtnOB1VAwcqhRbZzVUC6SQwCK0dVQDvfT42XDlVA"},"yaxis":"y","type":"scatter"},{"customdata":[["GoogLeNet_Weights.IMAGENET1K_V1",6.6]],"hovertemplate":"Fam\u00edlia=GoogLeNet\u003cbr\u003eGFLOPS=%{x}\u003cbr\u003e ...

# %% [markdown]
# Poucos parâmetros facilitam o treinamento do modelo. Poucos GFlops são importantes tanto para o treinamento quanto para utilizar o modelo para inferência.

# %% [markdown]
# ### Modelos timm
#
# Modelos da biblioteca Pytorch Image Models

# %%
import timm


def create_families(data, modules_to_highlight):

    models = []             # List of models
    model_to_module = {}    # Model name -> model family
    for module, filter in modules_to_highlight:
        timm_models = timm.list_models(filter=filter, module=module, 
                                       pretrained=True, include_tags=True)
        models.extend(timm_models)
        for item in timm_models:
            model_to_module[item] = module

    family = []
    for val in data['model']:
        if val in model_to_module:
            family.append(model_to_module[val])
        else:
            family.append('Outro')

    data['Família'] = family

def plot_data(data, title):

    fig = px.scatter(data, x='param_count', y='top1', color='Família', hover_name='model',
                    hover_data='model', log_x=True, title=title)
    fig.update_traces(marker={'size': 4})
    fig.show()

# Performance no ImageNet
data_in = pd.read_csv('../data/model_info/results-imagenet.csv', thousands=',')
# Performance em um dataset com imagens das mesmas classes do ImageNet
# mas coletadas e classificadas de forma independente
data_v2 = pd.read_csv('../data/model_info/results-imagenetv2-matched-frequency.csv', thousands=',')
# Performance de um dataset que contém variações do ImageNet, por exemplo
# imagens desenhadas à mão
data_sk = pd.read_csv('../data/model_info/results-sketch.csv', thousands=',')
# Performance de inferência dos modelos
data_inf = pd.read_csv('../data/model_info/benchmark-infer-amp-nhwc-pt210-cu121-rtx3090.csv')

modules_to_highlight = [('resnet', 'resnet50'), ('regnet', None), ('convnext', None), 
                        ('vision_transformer', 'vit*'), ('swin_transformer_v2', None), 
                        ('swin_transformer_v2_cr', None)]
create_families(data_in, modules_to_highlight)
plot_data(data_in, 'Acurácia dos modelos timm no ImageNet')
create_families(data_v2, modules_to_highlight)
plot_data(data_v2, 'Acurácia dos modelos timm no ImageNetv2')
create_families(data_sk, modules_to_highlight)
plot_data(data_sk, 'Acurácia dos modelos timm no ImageNet sketch')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="850b3e51-8a91-48ef-bc9d-b3d97f5a8092" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("850b3e51-8a91-48ef-bc9d-b3d97f5a8092")) {                    Plotly.newPlot(                        "850b3e51-8a91-48ef-bc9d-b3d97f5a8092",                        [{"customdata":[["eva02_large_patch14_448.mim_m38m_ft_in22k_in1k"],["eva02_large_patch14_448.mim_in22k_ft_in22k_in1k"],["eva_giant_patch14_560.m30m_ft_in22k_in1k"],["eva02_large_patch14_448.mim_in22k_ft_in1k"],["eva02_large_patch14_448.mim_m38m_ft_in1k"],["eva_giant_patch14_336.m30m_ft_in22k_in1k"],["eva_giant_patch14_336.clip_ft_in1k"],["eva_large_patch14_336.in22k_ft_in22k_in1k"],["eva_giant_patch14_224.clip_ft_in1k"],["eva02_base_patch14_448.mim_in22k_ft_in22k_in1k"],["eva_large_patch14_336.in22k_ft_in1k"],["beit_large_patch16_512.in22k_ft_in22k_in1k"],["eva_large_patch14_196.in22k_ft_in22k_in1k"],["maxvit_xlarge_tf_512.in21k_ft_in1k"],["beit_large_patch16_384.in22k_ft_in22k_in1k"],["beitv2_large_patch16_224.in1k_ft_in22k_in1k"],["tf_efficientnet_l2.ns_jft_in1k"],["maxvit_xlarge_tf_384.in21k_ft_in1k"],["eva02_base_patch14_448.mim_in22k_ft_in1k"],["tf_efficientnet_l2.ns_jft_in1k_475"],["maxvit_large_tf_512.in21k_ft_in1k"],["maxvit_base_tf_512.in21k_ft_in1k"],["caformer_b36.sail_in22k_ft_in1k_384"],["maxvit_large_tf_384.in21k_ft_in1k"],["eva_large_patch14_196.in22k_ft_in1k"],["maxvit_base_tf_384.in21k_ft_in1k"],["maxvit_rmlp_base_rw_384.sw_in12k_ft_in1k"],["deit3_large_patch16_384.fb_in22k_ft_in1k"],["convformer_b36.sail_in22k_ft_in1k_384"],["beit_large_patch16_224.in22k_ft_in22k_in1k"],["maxxvitv2_rmlp_base_rw_384.sw_in12k_ft_in1k"],["caformer_m36.sail_in22k_ft_in1k_384"],["caformer_b36.sail_in22k_ft_in1k"],["beitv2_large_patch16_224.in1k_ft_in1k"],["coatnet_rmlp_2_rw_384.sw_in12k_ft_in1k"],["seresnextaa201d_32x8d.sw_in12k_ft_in1k_384"],["deit3_huge_patch14_224.fb_in22k_ft_in1k"],["swin_large_patch4_window12_384.ms_in22k_ft_in1k"],["volo_d5_512.sail_in1k"],["convformer_b36.sail_in22k_ft_in1k"],["deit3_large_patch16_224.fb_in22k_ft_in1k"],["volo_d5_448.sail_in1k"],["maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k"],["convformer_m36.sail_in22k_ft_in1k_384"],["caformer_s36.sail_in22k_ft_in1k_384"],["tf_efficientnet_b7.ns_jft_in1k"],["tf_efficientnetv2_l.in21k_ft_in1k"],["beit_base_patch16_384.in22k_ft_in22k_in1k"],["volo_d4_448.sail_in1k"],["tf_efficientnetv2_xl.in21k_ft_in1k"],["deit3_base_patch16_384.fb_in22k_ft_in1k"],["seresnextaa101d_32x8d.sw_in12k_ft_in1k_288"],["maxxvitv2_rmlp_base_rw_224.sw_in12k_ft_in1k"],["maxvit_base_tf_512.in1k"],["caformer_m36.sail_in22k_ft_in1k"],["coatnet_2_rw_224.sw_in12k_ft_in1k"],["maxvit_large_tf_512.in1k"],["coatnet_rmlp_2_rw_224.sw_in12k_ft_in1k"],["volo_d3_448.sail_in1k"],["cait_m48_448.fb_dist_in1k"],["seresnextaa101d_32x8d.sw_in12k_ft_in1k"],["beitv2_base_patch16_224.in1k_ft_in22k_in1k"],["tiny_vit_21m_512.dist_in22k_ft_in1k"],["tf_efficientnet_b6.ns_jft_in1k"],["swin_base_patch4_window12_384.ms_in22k_ft_in1k"],["caformer_b36.sail_in1k_384"],["convformer_s36.sail_in22k_ft_in1k_384"],["dm_nfnet_f6.dm_in1k"],["swin_large_patch4_window7_224.ms_in22k_ft_in1k"],["maxvit_base_tf_384.in1k"],["maxvit_large_tf_384.in1k"],["vit_large_r50_s32_384.augreg_in21k_ft_in1k"],["caformer_m36.sail_in1k_384"],["convformer_m36.sail_in22k_ft_in1k"],["tiny_vit_21m_384.dist_in22k_ft_in1k"],["dm_nfnet_f5.dm_in1k"],["tf_efficientnet_b5.ns_jft_in1k"],["maxvit_small_tf_512.in1k"],["volo_d5_224.sail_in1k"],["cait_m36_384.fb_dist_in1k"],["volo_d2_384.sail_in1k"],["xcit_large_24_p8_384.fb_dist_in1k"],["tf_efficientnetv2_m.in21k_ft_in1k"],["efficientnet_b5.sw_in12k_ft_in1k"],["volo_d4_224.sail_in1k"],["dm_nfnet_f4.dm_in1k"],["xcit_medium_24_p8_384.fb_dist_in1k"],["deit3_large_patch16_384.fb_in1k"],[ ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="163a6089-5756-4294-975f-720dd4b81d5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("163a6089-5756-4294-975f-720dd4b81d5c")) {                    Plotly.newPlot(                        "163a6089-5756-4294-975f-720dd4b81d5c",                        [{"customdata":[["eva_giant_patch14_336.clip_ft_in1k"],["eva02_large_patch14_448.mim_in22k_ft_in1k"],["eva02_large_patch14_448.mim_m38m_ft_in1k"],["eva_giant_patch14_560.m30m_ft_in22k_in1k"],["eva02_large_patch14_448.mim_in22k_ft_in22k_in1k"],["eva02_large_patch14_448.mim_m38m_ft_in22k_in1k"],["eva_giant_patch14_336.m30m_ft_in22k_in1k"],["eva_giant_patch14_224.clip_ft_in1k"],["eva_large_patch14_336.in22k_ft_in1k"],["eva_large_patch14_336.in22k_ft_in22k_in1k"],["tf_efficientnet_l2.ns_jft_in1k_475"],["beitv2_large_patch16_224.in1k_ft_in22k_in1k"],["tf_efficientnet_l2.ns_jft_in1k"],["eva_large_patch14_196.in22k_ft_in22k_in1k"],["maxvit_base_tf_512.in21k_ft_in1k"],["eva_large_patch14_196.in22k_ft_in1k"],["maxvit_xlarge_tf_512.in21k_ft_in1k"],["maxvit_large_tf_512.in21k_ft_in1k"],["beit_large_patch16_512.in22k_ft_in22k_in1k"],["maxvit_xlarge_tf_384.in21k_ft_in1k"],["maxvit_large_tf_384.in21k_ft_in1k"],["eva02_base_patch14_448.mim_in22k_ft_in22k_in1k"],["beit_large_patch16_384.in22k_ft_in22k_in1k"],["maxvit_base_tf_384.in21k_ft_in1k"],["deit3_huge_patch14_224.fb_in22k_ft_in1k"],["eva02_base_patch14_448.mim_in22k_ft_in1k"],["deit3_large_patch16_384.fb_in22k_ft_in1k"],["caformer_b36.sail_in22k_ft_in1k_384"],["maxvit_rmlp_base_rw_384.sw_in12k_ft_in1k"],["beit_large_patch16_224.in22k_ft_in22k_in1k"],["beitv2_large_patch16_224.in1k_ft_in1k"],["deit3_large_patch16_224.fb_in22k_ft_in1k"],["tf_efficientnet_b7.ns_jft_in1k"],["coatnet_rmlp_2_rw_384.sw_in12k_ft_in1k"],["caformer_m36.sail_in22k_ft_in1k_384"],["caformer_b36.sail_in22k_ft_in1k"],["convformer_b36.sail_in22k_ft_in1k_384"],["volo_d5_512.sail_in1k"],["deit3_base_patch16_384.fb_in22k_ft_in1k"],["volo_d5_448.sail_in1k"],["volo_d4_448.sail_in1k"],["maxxvitv2_rmlp_base_rw_384.sw_in12k_ft_in1k"],["maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k"],["tf_efficientnetv2_xl.in21k_ft_in1k"],["tf_efficientnetv2_l.in21k_ft_in1k"],["caformer_s36.sail_in22k_ft_in1k_384"],["caformer_b36.sail_in1k_384"],["maxvit_base_tf_512.in1k"],["caformer_m36.sail_in22k_ft_in1k"],["seresnextaa201d_32x8d.sw_in12k_ft_in1k_384"],["maxvit_large_tf_512.in1k"],["seresnextaa101d_32x8d.sw_in12k_ft_in1k_288"],["tf_efficientnet_b6.ns_jft_in1k"],["convformer_b36.sail_in22k_ft_in1k"],["caformer_m36.sail_in1k_384"],["maxvit_large_tf_384.in1k"],["beitv2_base_patch16_224.in1k_ft_in22k_in1k"],["volo_d3_448.sail_in1k"],["swin_large_patch4_window12_384.ms_in22k_ft_in1k"],["vit_large_r50_s32_384.augreg_in21k_ft_in1k"],["coatnet_rmlp_2_rw_224.sw_in12k_ft_in1k"],["convformer_m36.sail_in22k_ft_in1k_384"],["beit_base_patch16_384.in22k_ft_in22k_in1k"],["seresnextaa101d_32x8d.sw_in12k_ft_in1k"],["tf_efficientnetv2_m.in21k_ft_in1k"],["cait_m48_448.fb_dist_in1k"],["tf_efficientnet_b5.ns_jft_in1k"],["resnext101_32x32d.fb_wsl_ig1b_ft_in1k"],["maxvit_base_tf_384.in1k"],["tiny_vit_21m_512.dist_in22k_ft_in1k"],["deit3_large_patch16_384.fb_in1k"],["beitv2_base_patch16_224.in1k_ft_in1k"],["coatnet_2_rw_224.sw_in12k_ft_in1k"],["xcit_large_24_p8_384.fb_dist_in1k"],["caformer_s36.sail_in22k_ft_in1k"],["caformer_s36.sail_in1k_384"],["volo_d5_224.sail_in1k"],["deit3_base_patch16_224.fb_in22k_ft_in1k"],["maxxvitv2_rmlp_base_rw_224.sw_in12k_ft_in1k"],["dm_nfnet_f6.dm_in1k"],["maxvit_small_tf_512.in1k"],["tiny_vit_21m_384.dist_in22k_ft_in1k"],["convformer_m36.sail_in1k_384"],["convformer_s36.sail_in22k_ft_in1k_384"],["convformer_m36.sail_in22k_ft_in1k"],["cait_m36_384.fb_dist_in1k"],["swin_large_patch4_window7_224.ms_in22k_ft_in1k"],[ ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="1c5b1799-1e9e-47a8-8a30-30690cc3035d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1c5b1799-1e9e-47a8-8a30-30690cc3035d")) {                    Plotly.newPlot(                        "1c5b1799-1e9e-47a8-8a30-30690cc3035d",                        [{"customdata":[["eva_giant_patch14_336.clip_ft_in1k"],["eva02_large_patch14_448.mim_m38m_ft_in22k_in1k"],["eva02_large_patch14_448.mim_m38m_ft_in1k"],["eva_giant_patch14_224.clip_ft_in1k"],["eva_giant_patch14_336.m30m_ft_in22k_in1k"],["eva02_large_patch14_448.mim_in22k_ft_in22k_in1k"],["eva_giant_patch14_560.m30m_ft_in22k_in1k"],["eva02_large_patch14_448.mim_in22k_ft_in1k"],["eva_large_patch14_336.in22k_ft_in1k"],["eva_large_patch14_196.in22k_ft_in1k"],["eva_large_patch14_336.in22k_ft_in22k_in1k"],["eva_large_patch14_196.in22k_ft_in22k_in1k"],["eva02_base_patch14_448.mim_in22k_ft_in22k_in1k"],["resnext101_32x32d.fb_wsl_ig1b_ft_in1k"],["beitv2_large_patch16_224.in1k_ft_in22k_in1k"],["eva02_base_patch14_448.mim_in22k_ft_in1k"],["resnext101_32x16d.fb_wsl_ig1b_ft_in1k"],["resnext101_32x16d.fb_swsl_ig1b_ft_in1k"],["beit_large_patch16_384.in22k_ft_in22k_in1k"],["beit_large_patch16_512.in22k_ft_in22k_in1k"],["resnext101_32x8d.fb_swsl_ig1b_ft_in1k"],["maxvit_rmlp_base_rw_384.sw_in12k_ft_in1k"],["maxvit_xlarge_tf_384.in21k_ft_in1k"],["maxvit_xlarge_tf_512.in21k_ft_in1k"],["maxvit_base_tf_512.in21k_ft_in1k"],["deit3_huge_patch14_224.fb_in22k_ft_in1k"],["maxvit_base_tf_384.in21k_ft_in1k"],["maxvit_large_tf_512.in21k_ft_in1k"],["maxvit_large_tf_384.in21k_ft_in1k"],["beit_large_patch16_224.in22k_ft_in22k_in1k"],["resnext101_32x8d.fb_wsl_ig1b_ft_in1k"],["deit3_large_patch16_384.fb_in22k_ft_in1k"],["maxxvitv2_rmlp_base_rw_384.sw_in12k_ft_in1k"],["caformer_b36.sail_in22k_ft_in1k_384"],["deit3_large_patch16_224.fb_in22k_ft_in1k"],["beitv2_large_patch16_224.in1k_ft_in1k"],["maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k"],["resnext101_32x4d.fb_swsl_ig1b_ft_in1k"],["convformer_b36.sail_in22k_ft_in1k_384"],["caformer_b36.sail_in22k_ft_in1k"],["convformer_b36.sail_in22k_ft_in1k"],["coatnet_rmlp_2_rw_384.sw_in12k_ft_in1k"],["vit_large_r50_s32_384.augreg_in21k_ft_in1k"],["tf_efficientnet_l2.ns_jft_in1k_475"],["maxxvitv2_rmlp_base_rw_224.sw_in12k_ft_in1k"],["caformer_m36.sail_in22k_ft_in1k_384"],["seresnextaa201d_32x8d.sw_in12k_ft_in1k_384"],["resnext50_32x4d.fb_swsl_ig1b_ft_in1k"],["swin_large_patch4_window12_384.ms_in22k_ft_in1k"],["tf_efficientnetv2_xl.in21k_ft_in1k"],["caformer_m36.sail_in22k_ft_in1k"],["beitv2_base_patch16_224.in1k_ft_in22k_in1k"],["coatnet_rmlp_2_rw_224.sw_in12k_ft_in1k"],["convformer_m36.sail_in22k_ft_in1k_384"],["convformer_m36.sail_in22k_ft_in1k"],["swin_large_patch4_window7_224.ms_in22k_ft_in1k"],["tf_efficientnetv2_l.in21k_ft_in1k"],["coatnet_2_rw_224.sw_in12k_ft_in1k"],["beit_base_patch16_384.in22k_ft_in22k_in1k"],["swin_base_patch4_window12_384.ms_in22k_ft_in1k"],["caformer_s36.sail_in22k_ft_in1k_384"],["maxvit_base_tf_512.in1k"],["vit_large_r50_s32_224.augreg_in21k_ft_in1k"],["tf_efficientnet_b7.ns_jft_in1k"],["tf_efficientnet_b6.ns_jft_in1k"],["deit3_base_patch16_384.fb_in22k_ft_in1k"],["tf_efficientnet_l2.ns_jft_in1k"],["tf_efficientnetv2_m.in21k_ft_in1k"],["deit3_base_patch16_224.fb_in22k_ft_in1k"],["tiny_vit_21m_512.dist_in22k_ft_in1k"],["convformer_s36.sail_in22k_ft_in1k_384"],["maxvit_large_tf_512.in1k"],["convformer_s36.sail_in22k_ft_in1k"],["caformer_s36.sail_in22k_ft_in1k"],["tiny_vit_21m_384.dist_in22k_ft_in1k"],["beit_base_patch16_224.in22k_ft_in22k_in1k"],["maxvit_base_tf_384.in1k"],["hrnet_w48_ssld.paddle_in1k"],["beitv2_base_patch16_224.in1k_ft_in1k"],["seresnextaa101d_32x8d.sw_in12k_ft_in1k_288"],["tf_efficientnet_b8.ap_in1k"],["maxvit_large_tf_384.in1k"],["tf_efficientnet_b5.ns_jft ...

# %%
def merge_tables(data_in, data_inf):
    """Merge results table with inference time table. Not all models are merged. 
    Doing this correctly requires doing string similarity, which is hard. 
    """
    
    indices = []
    for idx_in, row in data_in.iterrows():
        model = row['model']
        if '.' in model:
            name, tag = model.split('.')
        else:
            name = model
        name = name.lower()
        for idx_inf, row in data_inf.iterrows():
            model_inf = row['model']
            model_inf = model_inf.lower()
            model_inf = model_inf.replace('_in21ft1k', '').replace('_in22ft1k','')
            #if name in model_inf or model_inf in name:
            if name==model_inf:
                indices.append((idx_in, idx_inf))

    idx_in, idx_inf = zip(*indices)
    data_in_c = data_in.iloc[list(idx_in)].reset_index(drop=True)
    data_inf_c = data_inf.iloc[list(idx_inf)].reset_index(drop=True)
    data_inf_c = data_inf_c.drop(['model', 'param_count'], axis=1)
    data_merged = pd.concat([data_in_c, data_inf_c], axis=1)

    return data_merged

def plot_inference(data_merged, modules_to_highlight):
    
    # Use only models where input image has size 224 or 288 (larger sizes lead 
    # to larger inference times)
    data_norm = data_merged[
        (data_merged['infer_img_size']==224) | (data_merged['infer_img_size']==288)]
    # Use only models where batch size is 1024 (different values trivially 
    # change inference time)
    data_norm = data_norm[data_norm['infer_batch_size']==1024]
    create_families(data_norm, modules_to_highlight)

    fig = px.scatter(data_norm, x='infer_samples_per_sec', y='top1', 
                     color='Família', hover_name='model',
                    hover_data='model', log_x=True,
                    title='Número de imagens por segundo em modo inferência')
    fig.update_traces(marker={'size': 4})
    fig.show()

data_merged = merge_tables(data_in, data_inf)

# %%
#modules_to_highlight = [('convnext', 'convnext_base*'), ('vision_transformer', 
#                         'vit_base_patch16_224*'), 
#                        ('vision_transformer', 'vit_base_patch16_clip_224*')]

plot_inference(data_merged, modules_to_highlight)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="a1f40262-2c42-4164-b2d7-30a0cf2d9e06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a1f40262-2c42-4164-b2d7-30a0cf2d9e06")) {                    Plotly.newPlot(                        "a1f40262-2c42-4164-b2d7-30a0cf2d9e06",                        [{"customdata":[["eva_giant_patch14_224.clip_ft_in1k"],["beitv2_large_patch16_224.in1k_ft_in22k_in1k"],["beit_large_patch16_224.in22k_ft_in22k_in1k"],["caformer_m36.sail_in22k_ft_in1k_384"],["beitv2_large_patch16_224.in1k_ft_in1k"],["deit3_huge_patch14_224.fb_in22k_ft_in1k"],["deit3_large_patch16_224.fb_in22k_ft_in1k"],["convformer_m36.sail_in22k_ft_in1k_384"],["caformer_s36.sail_in22k_ft_in1k_384"],["seresnextaa101d_32x8d.sw_in12k_ft_in1k_288"],["caformer_m36.sail_in22k_ft_in1k"],["seresnextaa101d_32x8d.sw_in12k_ft_in1k"],["beitv2_base_patch16_224.in1k_ft_in22k_in1k"],["convformer_s36.sail_in22k_ft_in1k_384"],["caformer_m36.sail_in1k_384"],["convformer_m36.sail_in22k_ft_in1k"],["volo_d5_224.sail_in1k"],["volo_d4_224.sail_in1k"],["caformer_s36.sail_in22k_ft_in1k"],["caformer_s36.sail_in1k_384"],["deit3_base_patch16_224.fb_in22k_ft_in1k"],["beitv2_base_patch16_224.in1k_ft_in1k"],["convformer_m36.sail_in1k_384"],["caformer_s18.sail_in22k_ft_in1k_384"],["convformer_s36.sail_in22k_ft_in1k"],["volo_d3_224.sail_in1k"],["convformer_s36.sail_in1k_384"],["swin_base_patch4_window7_224.ms_in22k_ft_in1k"],["caformer_m36.sail_in1k"],["deit3_huge_patch14_224.fb_in1k"],["beit_base_patch16_224.in22k_ft_in22k_in1k"],["inception_next_base.sail_in1k_384"],["volo_d2_224.sail_in1k"],["tiny_vit_21m_224.dist_in22k_ft_in1k"],["caformer_s18.sail_in1k_384"],["convformer_s18.sail_in22k_ft_in1k_384"],["xcit_large_24_p16_224.fb_dist_in1k"],["coatnet_rmlp_1_rw2_224.sw_in12k_ft_in1k"],["xcit_small_24_p8_224.fb_dist_in1k"],["deit3_large_patch16_224.fb_in1k"],["resnetrs350.tf_in1k"],["dm_nfnet_f1.dm_in1k"],["davit_base.msft_in1k"],["seresnextaa101d_32x8d.ah_in1k"],["deit3_medium_patch16_224.fb_in22k_ft_in1k"],["rexnetr_300.sw_in12k_ft_in1k"],["resnetv2_152x2_bit.goog_in21k_ft_in1k"],["caformer_s36.sail_in1k"],["convformer_m36.sail_in1k"],["hrnet_w48_ssld.paddle_in1k"],["hrnet_w48_ssld.paddle_in1k"],["mvitv2_base.fb_in1k"],["gcvit_base.in1k"],["vit_large_r50_s32_224.augreg_in21k_ft_in1k"],["convformer_s18.sail_in1k_384"],["resmlp_big_24_224.fb_in22k_ft_in1k"],["seresnext101d_32x8d.ah_in1k"],["seresnext101d_32x8d.ah_in1k"],["resnext101_32x8d.fb_swsl_ig1b_ft_in1k"],["xcit_medium_24_p16_224.fb_dist_in1k"],["davit_small.msft_in1k"],["xcit_small_12_p8_224.fb_dist_in1k"],["seresnext101_32x8d.ah_in1k"],["seresnext101_32x8d.ah_in1k"],["resnext101_32x16d.fb_wsl_ig1b_ft_in1k"],["volo_d1_224.sail_in1k"],["efficientvit_b3.r288_in1k"],["resnetaa101d.sw_in12k_ft_in1k"],["resnetaa101d.sw_in12k_ft_in1k"],["inception_next_base.sail_in1k"],["caformer_s18.sail_in22k_ft_in1k"],["convformer_s36.sail_in1k"],["swin_s3_base_224.ms_in1k"],["tresnet_v2_l.miil_in21k_ft_in1k"],["gcvit_small.in1k"],["xcit_small_24_p16_224.fb_dist_in1k"],["focalnet_base_lrf.ms_in1k"],["resnetv2_152x2_bit.goog_teacher_in21k_ft_in1k_384"],["xcit_small_24_p8_224.fb_in1k"],["focalnet_base_srf.ms_in1k"],["efficientnetv2_rw_s.ra2_in1k"],["efficientvit_b3.r256_in1k"],["deit3_base_patch16_224.fb_in1k"],["mvitv2_small.fb_in1k"],["pit_b_distilled_224.in1k"],["repvit_m2_3.dist_450e_in1k"],["pvt_v2_b5.in1k"],["convformer_s18.sail_in22k_ft_in1k"],["pvt_v2_b4.in1k"],["twins_svt_large.in1k"],["caformer_s18.sail_in1k"],["efficientformerv2_l.snap_dist_in1k"],["swin_base_patch4_window7_224.ms_in1k"],["coat_lite_medium.in1k"],["coatnet_1_rw_224.sw_in1k"],["resmlp_big_24_224.fb_distilled_in1k"],["inception_next_small.sail_in1k"],["nest_base_jx.goog_in1k"],["repvit_m2_3.dist_300e_in1k"],["focalnet_s ...

# %% [markdown]
# O gráfico acima mostra o número de imagens por segundo que uma RTX-3090 consegue processar, usando batch size 1024.
