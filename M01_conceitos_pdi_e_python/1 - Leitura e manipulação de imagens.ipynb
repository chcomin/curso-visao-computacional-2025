# %% [markdown]
# # Leitura e manipulação de imagens
#
# Este notebook apresenta alguns conceitos básicos sobre processamento de imagens.

# %%
# matplotlib: biblioteca para visualização de dados
import matplotlib.pyplot as plt

# numpy: biblioteca para manipulação de arrays e matrizes
import numpy as np

# PIL (Pillow): biblioteca para leitura e escrita de imagens no disco
from PIL import Image

# %% [markdown]
# ### Informações sobre uma imagem
#
# É sempre importante verificar como os valores de intensidade de uma imagem estão sendo representados

# %%
# Leitura da imagem do disco utilizando a biblioteca Pillow
img = Image.open("../data/cameraman/cameraman.tiff")
print(type(img))

# Conversão da imagem para um array numpy
img = np.array(img)
print(type(img))
# Out:
# <class 'PIL.TiffImagePlugin.TiffImageFile'>
# <class 'numpy.ndarray'>

# %%
def info(img):
    print(f"Resolução: {img.shape}")
    print(f"Tipo de dados: {img.dtype}")
    print(f"Valor mínimo: {img.min()}")
    print(f"Valor máximo: {img.max()}\n")

info(img)
# Out:
# Resolução: (256, 256)
# Tipo de dados: uint8
# Valor mínimo: 7
# Valor máximo: 253

# %% [markdown]
# ### Cálculo do histograma de uma imagem

# %%
plt.imshow(img, "gray")
plt.figure()
# Lembrar de transformar a imagem em um array 1D
_ = plt.hist(img.flatten(), bins=50)

# %% [markdown]
# ### Aplicação da transformação gamma para tornar a imagem mais escura

# %%
exp = 4.
img_transf = img.astype(float)**exp
plt.figure(figsize=[9, 4])
plt.subplot(1, 2, 1)
plt.imshow(img_transf, "gray")
plt.subplot(1, 2, 2)
_ = plt.hist(img_transf.flatten(), 50)

# %% [markdown]
# Lembrando que a nova imagem possui valores float e não está no intervalo [0, 255]

# %%
print(img_transf.dtype, np.min(img_transf), np.max(img_transf))
# Out:
# float64 2401.0 4097152081.0

# %%
# Normalização da imagem para o intervalo [0, 255]
img_norm = img_transf - np.min(img_transf)
img_norm = 255*img_norm/np.max(img_norm)
img_norm = img_norm.astype(np.uint8)

print(img_norm.dtype, np.min(img_norm), np.max(img_norm))
# Out:
# uint8 0 255

# %% [markdown]
# ### Cuidados com formato de imagem

# %%
root = "../data/cameraman/"
names = ["cameraman.tiff", "cameraman.jpeg", "cameraman2.tiff",
         "cameraman3.tiff", "cameraman4.tiff", "cameraman.png"]

for name in names:
    img = Image.open(root+name)
    plt.figure()
    plt.imshow(img, "gray")
    plt.title(name)

# %%
# Mas as imagens são bem diferentes
for name in names:
    img = np.array(Image.open(root+name))
    info(img)
# Out:
# Resolução: (256, 256)
# Tipo de dados: uint8
# Valor mínimo: 7
# Valor máximo: 253
#
# Resolução: (256, 256)
# Tipo de dados: uint8
# Valor mínimo: 0
# Valor máximo: 255
#
# Resolução: (256, 256, 3)
# Tipo de dados: uint8
# Valor mínimo: 7
# Valor máximo: 253
#
# Resolução: (256, 256, 4)
# Tipo de dados: uint8
# Valor mínimo: 7
# Valor máximo: 255
#
# Resolução: (256, 256)
# Tipo de dados: uint16
# Valor mínimo: 1799
# Valor máximo: 65021
#
# Resolução: (256, 256)
# Tipo de dados: uint8
# Valor mínimo: 7
# Valor máximo: 253

# %% [markdown]
# As imagens são do tipo:
#
# * img_or: uint8 de 1 canal
# * img_jpeg: uint8 de 1 canal mas com artefatos de compressão do formato jpeg
# * img2: uint8 de 3 canais (RGB)
# * img3: uint8 de 4 canais
# * img4: uint16 de 1 canal
# * img_png: float32 de 1 canal, com valores entre 0 e 1
